# %% [markdown]
# <a href="https://colab.research.google.com/github/marizeteteixeira/FirstRepo/blob/main/ExemploOpenImage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install Pillow

# %%
import PIL
from PIL import Image
import urllib.request
import io, sys

# %%
# Abrir uma imagem
imagem = Image.open('/content/img/IMG_1744.JPG')

reimagem = imagem.resize((imagem.width // 8, imagem.height // 8))
reimagem
# Out:
# <PIL.Image.Image image mode=RGB size=432x288>
